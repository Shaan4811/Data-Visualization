# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
sales = [75000, 78000, 82000, 85000, 87000, 90000, 93000, 95000, 100000, 105000, 110000, 115000]

# %%
plt.plot(sales)

# %%
plt.plot(sales);

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
plt.plot(months,sales);

# %%
plt.plot(months,sales,marker='d');

# %%
plt.plot(months,sales,marker='o');

# %%
plt.plot(months,sales,marker='s');

# %%
plt.plot(months,sales,marker='d',color='b');

# %%
plt.plot(months,sales,marker='d',color='r');

# %%
plt.plot(months,sales,marker='d',color='g');

# %%
plt.plot(months,sales,marker='d',color='pink');

# %% [markdown]
# ## customozinhg labels

# %%
plt.plot(months,sales,marker='d',color='r')
plt.xlabel('months')
plt.ylabel('sales');

# %%
plt.plot(months,sales,marker='d',color='r')
plt.xlabel('months')
plt.ylabel('sales')
plt.title('sales over months');

# %%
plt.figure(figsize=(15,10))
plt.plot(months,sales,marker='d',color='r')
plt.xlabel('months')
plt.ylabel('sales')
plt.title('sales over months');

# %%
plt.figure(figsize=(6,4))
plt.plot(months,sales,marker='d',color='r')
plt.xlabel('months')
plt.ylabel('sales')
plt.xticks(rotation=90)
plt.title('sales over months');

# %%
sales2 = [65000, 74000, 79000, 84000, 87000, 90000, 95000, 97000, 100000, 106000, 130000, 145000]

# %%
plt.figure(figsize=(6,4))
plt.plot(months,sales,marker='d',color='r')
plt.plot(months,sales2,marker='o',color='g')
plt.xlabel('months')
plt.ylabel('sales')
plt.xticks(rotation=90)
plt.title('sales over months');

# %%
plt.figure(figsize=(6,4))
plt.plot(months,sales,marker='d',color='r')
plt.plot(months,sales2,marker='o',color='g')
plt.xlabel('months')
plt.ylabel('sales')
plt.legend(['c1','c2'])
plt.xticks(rotation=90)
plt.title('sales over months');

# %%
# sales of a week
Units_Sold= [20, 35, 15, 40, 30, 25, 45]
Units_Sold1= [25, 40, 45, 50, 40, 25, 55]
Product= ['Product A', 'Product B', 'Product D', 'Product E', 'Product F', 'Product G', 'Product H']

# %%
plt.figure(figsize=(8,6))
plt.plot(Units_Sold,Product,marker='o',color='b')
plt.plot(Units_Sold1,Product,marker='s',color='r')
plt.xlabel('Product')
plt.ylabel('Units_Sold')
plt.legend(['c1','c2'])
plt.title('sales of week')
plt.grid();

# %% [markdown]
# ## barplot

# %%
plt.figure(figsize=(6,4))
plt.bar(Product,Units_Sold)
plt.xlabel('Product')
plt.ylabel('Units_solds')
plt.xticks(rotation=90)
plt.title('sales of week');

# %%
plt.barh(Product,Units_Sold);

# %%
plt.barh(Product,Units_Sold,color='g');

# %%
plt.barh(Product,Units_Sold)
plt.grid()

# %%
plt.figure(figsize=(6,4))
plt.barh(Product,Units_Sold,color='r')
plt.xlabel('Product')
plt.ylabel('Units_solds')
plt.xticks(rotation=90)
plt.title('sales of week')
plt.grid();

# %% [markdown]
# ## histplot

# %%
import random
import pandas as pd
import numpy as np
data = {
    'Age': np.random.randint(20, 60, size=100),  # Random ages between 20 and 60
    'Salary': np.random.randint(30000, 100000, size=100),  # Random salaries
    'YearsAtCompany': np.random.randint(1, 20, size=100)  # Random years at the company
}

# %%
pd.DataFrame(data)
# Out:
#     Age  Salary  YearsAtCompany
# 0    25   69404               7
# 1    20   88700               7
# 2    46   93254               2
# 3    26   31036               7
# 4    24   69234               8
# ..  ...     ...             ...
# 95   49   34197              13
# 96   36   93435              18
# 97   29   67771               2
# 98   22   51048              19
# 99   54   52719               4
#
# [100 rows x 3 columns]

# %%
plt.hist(data['Salary'],bins=10,edgecolor='black');

# %% [markdown]
# ## 11-09-24

# %% [markdown]
# ## stacked bar

# %%
data = {
    'Quarter': ['Q1', 'Q2', 'Q3', 'Q4'],
    'Product A': [10, 20, 30, 40],
    'Product B': [20, 25, 35, 45],
    'Product C': [30, 30, 40, 50]
}
df = pd.DataFrame(data)

# %%
df.set_index('Quarter',inplace=True)

# %%
df.plot(kind='bar',colormap='magma',stacked=True,figsize=(8,6));

# %%
data1 = {
    'Region': ['North', 'South', 'East', 'West'],
    'Sedans': [150, 200, 180, 220],
    'SUVs': [120, 180, 160, 200],
    'Trucks': [80, 100, 90, 120]
}

# %%
df1=pd.DataFrame(data1)

# %%
df1.set_index('Region',inplace=True)

# %%
df1.plot(kind='hist',colormap='viridis',figsize=(6,4),ylabel='Sedans-suv-trucks',xlabel='Region',edgecolor='black');

# %%
df1.plot(kind='bar',colormap='viridis',figsize=(6,4),ylabel='Sedans-suv-trucks',xlabel='Region',edgecolor='black');

# %% [markdown]
# ## ----------

# %%
import numpy as np
import pandas as pd
np.random.seed(42)
data2={
    'F1':np.random.normal(loc=50,scale=10,size=500),
    'F2':np.random.normal(loc=55,scale=10,size=500),
    'F3':np.random.normal(loc=60,scale=15,size=500)
}

# %%
df2=pd.DataFrame(data2)

# %%
df2
# Out:
#             F1         F2         F3
# 0    54.967142  64.261775  80.990332
# 1    48.617357  74.094166  73.869505
# 2    56.476885  41.014324  60.894456
# 3    65.230299  60.629692  50.295948
# 4    47.658466  48.493574  70.473350
# ..         ...        ...        ...
# 495  55.389100  52.188997  90.091393
# 496  39.627538  72.976865  90.922554
# 497  48.096613  61.408429  78.125493
# 498  41.243817  49.288210  75.360938
# 499  36.172003  60.725828  68.887904
#
# [500 rows x 3 columns]

# %%
df2.plot(kind='hist',colormap='plasma',edgecolor='black');

# %%
df2.hist(bins=10,edgecolor='black',color='g')
plt.grid(False)
plt.suptitle('histplot of data');

# %% [markdown]
# ## -----------------------------------

# %%
np.random.seed(42)
data3={
    'q1':np.random.normal(loc=30,scale=15,size=100),
    'q2':np.random.normal(loc=35,scale=20,size=100),
    'q3':np.random.normal(loc=40,scale=25,size=100)
}

# %%
df3=pd.DataFrame(data3)

# %%
df3
# Out:
#            q1         q2         q3
# 0   37.450712   6.692585  48.944684
# 1   27.926035  26.587094  54.019613
# 2   39.715328  28.145710  67.076281
# 3   52.845448  18.954455  66.345051
# 4   26.487699  31.774286   5.558266
# ..        ...        ...        ...
# 95   8.047276  42.706348  22.677260
# 96  34.441804  17.322851  62.489997
# 97  33.915829  38.074502  47.682488
# 98  30.076702  36.164174  60.321553
# 99  26.481193  12.140594  55.740721
#
# [100 rows x 3 columns]

# %%
df3.hist(bins=10,edgecolor='black',color='r')
plt.suptitle('histplot od data');

# %% [markdown]
# ## ---------------------------------

# %%
orange=pd.read_csv('/Users/shaan/Desktop/data analytics/Matplotlib/docs/Orange Quality Data.csv')

# %%
orange
# Out:
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 0          7.5         180              12.0           3.2             2.0
# 1          8.2         220              10.5           3.4             3.0
# 2          6.8         150              14.0           3.0             1.0
# 3          9.0         250               8.5           3.8             4.0
# 4          8.5         210              11.5           3.3             2.5
# ..         ...         ...               ...           ...             ...
# 236        8.0         194              10.9           3.6             5.0
# 237        7.4         275               8.5           3.5             5.0
# 238        7.5         196              15.7           3.0             3.0
# 239        7.2         251               9.8           4.3             3.0
# 240        7.3         282              10.5           2.9             4.0
#
# ...

# %%
orange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Size (cm)           241 non-null    float64
#  1   Weight (g)          241 non-null    int64
#  2   Brix (Sweetness)    241 non-null    float64
#  3   pH (Acidity)        241 non-null    float64
#  4   Softness (1-5)      241 non-null    float64
#  5   HarvestTime (days)  241 non-null    int64
#  6   Ripeness (1-5)      241 non-null    float64
#  7   Color               241 non-null    object
#  8   Variety             241 non-null    object
#  9   Blemishes (Y/N)     241 non-null    object
#  10  Quality (1-5)       241 non-null    float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 20.8+ KB

# %%
orange.describe()
# Out:
#         Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# count  241.000000  241.000000        241.000000    241.000000      241.000000
# mean     7.844813  205.128631         10.907884      3.473900        3.072614
# std      1.086002   56.461012          2.760446      0.421007        1.323630
# min      6.000000  100.000000          5.500000      2.800000        1.000000
# 25%      6.900000  155.000000          8.500000      3.200000        2.000000
# 50%      7.800000  205.000000         11.000000      3.400000        3.000000
# 75%      8.700000  252.000000         13.400000      3.800000        4.000000
# max     10.000000  300.000000         16.000000      4.400000        5.000000
#
#        HarvestTime (days)  Ripeness (1-5)  Quality (1-5)
# count          241.000000      241.000000     241.000000
# mean            15.344398        3.599585       3.817427
# std              5.323852        1.205214       1.014410
# ...

# %%
orange.describe().T
# Out:
#                     count        mean        std    min    25%    50%    75%  \
# Size (cm)           241.0    7.844813   1.086002    6.0    6.9    7.8    8.7
# Weight (g)          241.0  205.128631  56.461012  100.0  155.0  205.0  252.0
# Brix (Sweetness)    241.0   10.907884   2.760446    5.5    8.5   11.0   13.4
# pH (Acidity)        241.0    3.473900   0.421007    2.8    3.2    3.4    3.8
# Softness (1-5)      241.0    3.072614   1.323630    1.0    2.0    3.0    4.0
# HarvestTime (days)  241.0   15.344398   5.323852    4.0   11.0   15.0   20.0
# Ripeness (1-5)      241.0    3.599585   1.205214    1.0    3.0    4.0    4.5
# Quality (1-5)       241.0    3.817427   1.014410    1.0    3.0    4.0    4.5
#
#                       max
# Size (cm)            10.0
# Weight (g)          300.0
# Brix (Sweetness)     16.0
# pH (Acidity)          4.4
# Softness (1-5)        5.0
# HarvestTime (days)   25.0
# Ripeness (1-5)        5.0
# Quality (1-5)         5.0

# %%
orange.isnull().sum()
# Out:
# Size (cm)             0
# Weight (g)            0
# Brix (Sweetness)      0
# pH (Acidity)          0
# Softness (1-5)        0
# HarvestTime (days)    0
# Ripeness (1-5)        0
# Color                 0
# Variety               0
# Blemishes (Y/N)       0
# Quality (1-5)         0
# dtype: int64

# %%
#takeway- null ndeeel dropnull kodkkka

# %%
orange.duplicated().sum()
# Out:
# 0

# %%
# takeway -duplicate ndeel drop duplictes()kodkka

# %%
orange['Color'].value_counts()
# Out:
# Color
# Deep Orange      75
# Light Orange     64
# Orange-Red       55
# Orange           38
# Yellow-Orange     9
# Name: count, dtype: int64

# %%
o=orange.groupby(['Color'])

# %%
o.get_group('Deep Orange')
# Out:
# /var/folders/q7/zzr8qqg13dx8q_qrsdxqmbn40000gn/T/ipykernel_2059/2913380172.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   o.get_group('Deep Orange')
#      Size (cm)  Weight (g)  Brix (Sweetness)  pH (Acidity)  Softness (1-5)  \
# 1          8.2         220              10.5           3.4             3.0
# 8          8.8         240               7.5           4.0             5.0
# 11         7.8         183              14.8           3.7             2.0
# 13         7.0         140              11.0           3.2             2.5
# 17         9.6         218              14.1           4.2             4.0
# ..         ...         ...               ...           ...             ...
# 225        6.4         261              14.6           3.2             2.0
# ...

# %% [markdown]
# ## 12-09-24

# %% [markdown]
# ## BOXPLOT

# %%
# * The plot displays a box that represents the interquartile range (IQR).
# * The bottom/left of the box is the 25th percentile (i.e., Q1) while the top/right of the box is the 75th percentile (that is, Q3). 
# * The orange line going through the box is the median.
# * The two lines extending above and below the box are the whiskers.
# * The top of the upper whisker is the "maximum" value, which is calculated using Q1 – 1.5*IQR.
# * The bottom of the lower whisker is the "minimum" value, which is calculate

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(42)
data={
    'Category A':np.random.normal(50,10,100),
    'Category B':np.random.normal(60,20,100),
    'Category C':np.random.normal(55,5,100),
    'Category D':np.append(np.random.normal(45,10,95),[100,105,110,115,120])
}
data=pd.DataFrame(data)

# %%
data
# Out:
#     Category A  Category B  Category C  Category D
# 0    54.967142   31.692585   56.788937   36.710050
# 1    48.617357   51.587094   57.803923   39.398190
# 2    56.476885   53.145710   60.415256   52.472936
# 3    65.230299   43.954455   60.269010   51.103703
# 4    47.658466   56.774286   48.111653   44.790984
# ..         ...         ...         ...         ...
# 95   35.364851   67.706348   51.535452  100.000000
# 96   52.961203   42.322851   59.497999  105.000000
# 97   52.610553   63.074502   56.536498  110.000000
# 98   50.051135   61.164174   59.064311  115.000000
# 99   47.654129   37.140594   58.148144  120.000000
#
# [100 rows x 4 columns]

# %%
plt.boxplot(data['Category A']);

# %%
plt.boxplot([data['Category A'],data['Category B']]);

# %%
data.boxplot(labels=data.columns);

# %% [markdown]
# ## ------------------------------------------

# %%
np.random.seed(42)
data1={
    'd1':np.random.randint(1,100,50),
    'd2':np.random.randint(1,90,50),
    'd3':np.random.randint(1,80,50),
    'd4':np.random.randint(1,70,50)
}
data1=pd.DataFrame(data1)

# %%
data1
# Out:
#     d1  d2  d3  d4
# 0   52   4  65  59
# 1   93  89  71  28
# 2   15  60   9  66
# 3   72  14   1  42
# 4   61   9   8  45
# 5   21  53  63  62
# 6   83   2  11  57
# 7   87  84   8   6
# 8   75  60  35  28
# 9   75  71  35  28
# 10  88  44  33  44
# 11  24   8   5  30
# 12   3  47  41  62
# 13  22  35  28  62
# 14  53  78   7   1
# 15   2  81  73  27
# 16  88  36  72  62
# 17  30  50  12   3
# 18  38   4  34  27
# 19   2   2  33   9
# 20  64   6  48  62
# 21  60  54  23  37
# 22  21   4  62  51
# 23  33  54  37  44
# 24  76  63  44  24
# 25  58  18  35  59
# 26  22  44  65  32
# 27  89  34  47  52
# 28  49  74  78  62
# 29  91  62   3  58
# 30  59  14   1  52
# 31  42  48   5  12
# 32  92  15  14  39
# 33  60  72  27   2
# 34  80  78   9   3
# 35  15  87  79  56
# 36  62  62  15  59
# 37  62  40  42   2
# 38  47  85  77   2
# 39  62  80  51  54
# 40  51  82  63   1
# 41  55  53  52  19
# 42  64  24   4   2
# 43   3  26  23  53
# 44  51  89  15  44
# 45   7  60  43  32
# ...

# %%
data1.boxplot(labels=data1.columns);

# %% [markdown]
# ## violineplot

# %%
plt.violinplot(data1['d1']);

# %%
plt.violinplot([data1['d1'],data1['d2']]);

# %% [markdown]
# ## 18/09/24

# %% [markdown]
# ## Scatterplot

# %%
np.random.seed(42)
data={
    'a':np.random.randint(1,100,10),
    'b':np.random.randint(1,50,10)
    
}
data=pd.DataFrame(data)

# %%
data
# Out:
#     a   b
# 0  52  24
# 1  93  36
# 2  15  40
# 3  72  24
# 4  61   3
# 5  21  22
# 6  83   2
# 7  87  24
# 8  75  44
# 9  75  30

# %%
plt.scatter(data['a'],data['b']);

# %%
plt.scatter(data['a'],data['b'],edgecolor='black',alpha=0.2,color='r')
plt.title('Random')
plt.xlabel('first')
plt.ylabel('second');

# %% [markdown]
# ## pie chart

# %% [markdown]
# <!-- labels: A list of labels for each slice of the pie.
# sizes: A list of numerical values that determine the size of each slice. The total of these values is used to determine the proportional size of each slice.
# colors: (Optional) A list of colors for each slice.
# explode: (Optional) A tuple that indicates how much to "explode" or separate each slice from the pie. For example, (0.1, 0, 0, 0) will pull the first slice out by 0.1 units.
# autopct: (Optional) A string format to label the slices with their percentage value (e.g., '%1.1f%%').
# shadow: (Optional) Adds a shadow to the pie chart.
# startangle: (Optional) Rotates the chart to start from a different angle (e.g., 140 degrees). -->

# %%
label=['category 1','category 2','category 3','category 4']
sizes=[20,30,40,50]

# %%
plt.pie(sizes,labels=label,explode=(0.1,0,0,0));

# %%
plt.pie(sizes,labels=label,explode=(0.1,0,0,0),shadow=True);

# %%
plt.pie(sizes,labels=label,explode=(0.1,0,0,0),shadow=True,autopct="%1.0f%%");

# %%
plt.pie(sizes,labels=label,explode=(0.1,0,0,0),shadow=True,autopct="%1.0f%%",startangle=90);

# %%
plt.pie(sizes,labels=label,explode=(0.1,0,0,0),shadow=True,autopct="%1.2f%%",startangle=90,colors=['r','g','skyblue','yellow']);

# %% [markdown]
# ## Q2

# %%
products=['product 1','product 2','product 3','product 4']
sales=[20,40,60,80]
color=['skyblue','r','lightgreen','brown']

# %%
plt.pie(sales,labels=products,explode=(0.2,0,0,0),shadow=True,autopct="%1.1f%%",colors=color);
