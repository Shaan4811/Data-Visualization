# %%
import pandas as pd

# %%
fortune=pd.read_csv('/Users/shaan/Desktop/data analytics/pandas/pandas_docs/fortune1000.xls')

# %%
fortune
# Out:
#                              Company  Revenues  Profits  Employees  \
# 0                            Walmart  500343.0   9862.0    2300000
# 1                        Exxon Mobil  244363.0  19710.0      71200
# 2                 Berkshire Hathaway  242137.0  44940.0     377000
# 3                              Apple  229234.0  48351.0     123000
# 4                 UnitedHealth Group  201159.0  10558.0     260000
# ..                               ...       ...      ...        ...
# 995         SiteOne Landscape Supply    1862.0     54.6       3664
# 996  Charles River Laboratories Intl    1858.0    123.4      11800
# 997                        CoreLogic    1851.0    152.2       5900
# 998                     Ensign Group    1849.0     40.5      21301
# 999                              HCP    1848.0    414.2        190
#
#                 Sector                                  Industry
# 0            Retailing                     General Merchandisers
# ...

# %%
profit=fortune['Profits'].head(10)

# %%
sector=fortune['Sector'].head(10)

# %%
plt.plot(sector,profit);

# %%
plt.plot(sector,profit,marker='*')

# %%
plt.plot(sector,profit,marker='*',color='r')

# %%
plt.plot(sector,profit,marker='*',color='r')
plt.xlabel('sector')
plt.ylabel('profit');

# %%
plt.figure(figsize=(8,6))
plt.plot(sector,profit,marker='*',color='r')
plt.xlabel('sector')
plt.ylabel('profit');

# %%
plt.figure(figsize=(8,6))
plt.plot(sector,profit,marker='*',color='r')
plt.xlabel('sector')
plt.ylabel('profit')
plt.xticks(rotation=90);

# %%
employee=fortune['Employees'].head(10)

# %%
plt.plot(sector,employee,marker='o',color='g')

# %%
plt.figure(figsize=(8,6))
plt.plot(sector,profit,marker='*',color='r')
plt.plot(sector,employee,marker='o',color='g')
plt.xlabel('sector')
plt.ylabel('profit')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(8,6))
plt.plot(sector,profit,marker='*',color='r')
plt.plot(sector,employee,marker='o',color='g')
plt.xlabel('sector')
plt.ylabel('profit')
plt.legend(['c1','c2'])
plt.xticks(rotation=90);

# %%
fortune['Company'].head(10)
# Out:
# 0               Walmart
# 1           Exxon Mobil
# 2    Berkshire Hathaway
# 3                 Apple
# 4    UnitedHealth Group
# 5              McKesson
# 6            CVS Health
# 7            Amazon.com
# 8                  AT&T
# 9        General Motors
# Name: Company, dtype: object

# %%
fortune['Sector'].head()
# Out:
# 0      Retailing
# 1         Energy
# 2     Financials
# 3     Technology
# 4    Health Care
# Name: Sector, dtype: object

# %%
plt.barh(fortune['Sector'],fortune['Revenues'],color='green');

# %%
plt.hist(fortune['Sector'],bins=10,edgecolor='black')
plt.xticks(rotation=90)
plt.xlabel('Sectors')
plt.title('Data');

# %%
df1.set_index('Region',inplace=True)

# %%
df1.plot(kind='hist',colormap='viridis',figsize=(6,4),ylabel='Sedans-suv-trucks',xlabel='Region',edgecolor='black');

# %%
df1.plot(kind='bar',colormap='viridis',figsize=(6,4),ylabel='Sedans-suv-trucks',xlabel='Region',edgecolor='black');

# %%
import numpy as np
