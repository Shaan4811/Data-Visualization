# %%
import pandas as pd

# %%
covid=pd.read_csv('/Users/shaan/Desktop/data analytics/Matplotlib/docs/ECDC_COVID_19.csv')

# %%
covid
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-04-08    8      4  2020     30       4             Afghanistan
# 1     2020-04-07    7      4  2020     38       0             Afghanistan
# 2     2020-04-06    6      4  2020     29       2             Afghanistan
# 3     2020-04-05    5      4  2020     35       1             Afghanistan
# 4     2020-04-04    4      4  2020      0       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9508  2020-03-25   25      3  2020      0       0                Zimbabwe
# 9509  2020-03-24   24      3  2020      0       1                Zimbabwe
# 9510  2020-03-23   23      3  2020      0       0                Zimbabwe
# 9511  2020-03-22   22      3  2020      1       0                Zimbabwe
# 9512  2020-03-21   21      3  2020      1       0                Zimbabwe
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9513 entries, 0 to 9512
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dateRep                  9513 non-null   object
#  1   day                      9513 non-null   int64
#  2   month                    9513 non-null   int64
#  3   year                     9513 non-null   int64
#  4   cases                    9513 non-null   int64
#  5   deaths                   9513 non-null   int64
#  6   countriesAndTerritories  9513 non-null   object
#  7   geoId                    9488 non-null   object
#  8   countryterritoryCode     9324 non-null   object
#  9   popData2018              9370 non-null   float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 743.3+ KB

# %%
covid.isnull().sum()
# Out:
# dateRep                      0
# day                          0
# month                        0
# year                         0
# cases                        0
# deaths                       0
# countriesAndTerritories      0
# geoId                       25
# countryterritoryCode       189
# popData2018                143
# dtype: int64

# %%
covid.duplicated().sum()
# Out:
# 0

# %%
covid.describe()
# Out:
#                day        month         year         cases       deaths  \
# count  9513.000000  9513.000000  9513.000000   9513.000000  9513.000000
# mean     15.548828     2.591822  2019.992957    146.314517     8.564911
# std       9.427045     1.284901     0.083631   1141.114073    71.611262
# min       1.000000     1.000000  2019.000000     -9.000000     0.000000
# 25%       7.000000     2.000000  2020.000000      0.000000     0.000000
# 50%      16.000000     3.000000  2020.000000      0.000000     0.000000
# 75%      24.000000     3.000000  2020.000000     13.000000     0.000000
# max      31.000000    12.000000  2020.000000  34272.000000  2004.000000
#
#         popData2018
# count  9.370000e+03
# mean   6.431196e+07
# std    2.015642e+08
# min    1.000000e+03
# 25%    3.545883e+06
# 50%    1.062716e+07
# 75%    4.272314e+07
# max    1.392730e+09

# %%
covid.describe().T
# Out:
#               count          mean           std     min        25%  \
# day          9513.0  1.554883e+01  9.427045e+00     1.0        7.0
# month        9513.0  2.591822e+00  1.284901e+00     1.0        2.0
# year         9513.0  2.019993e+03  8.363089e-02  2019.0     2020.0
# cases        9513.0  1.463145e+02  1.141114e+03    -9.0        0.0
# deaths       9513.0  8.564911e+00  7.161126e+01     0.0        0.0
# popData2018  9370.0  6.431196e+07  2.015642e+08  1000.0  3545883.0
#
#                     50%         75%           max
# day                16.0        24.0  3.100000e+01
# month               3.0         3.0  1.200000e+01
# year             2020.0      2020.0  2.020000e+03
# cases               0.0        13.0  3.427200e+04
# deaths              0.0         0.0  2.004000e+03
# popData2018  10627165.0  42723139.0  1.392730e+09

# %%
covid
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-04-08    8      4  2020     30       4             Afghanistan
# 1     2020-04-07    7      4  2020     38       0             Afghanistan
# 2     2020-04-06    6      4  2020     29       2             Afghanistan
# 3     2020-04-05    5      4  2020     35       1             Afghanistan
# 4     2020-04-04    4      4  2020      0       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9508  2020-03-25   25      3  2020      0       0                Zimbabwe
# 9509  2020-03-24   24      3  2020      0       1                Zimbabwe
# 9510  2020-03-23   23      3  2020      0       0                Zimbabwe
# 9511  2020-03-22   22      3  2020      1       0                Zimbabwe
# 9512  2020-03-21   21      3  2020      1       0                Zimbabwe
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
country=covid.groupby('countriesAndTerritories')

# %%
country

# %%
afg=country.get_group('Afghanistan')

# %%
afg
# Out:
#        dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0   2020-04-08    8      4  2020     30       4             Afghanistan    AF
# 1   2020-04-07    7      4  2020     38       0             Afghanistan    AF
# 2   2020-04-06    6      4  2020     29       2             Afghanistan    AF
# 3   2020-04-05    5      4  2020     35       1             Afghanistan    AF
# 4   2020-04-04    4      4  2020      0       0             Afghanistan    AF
# ..         ...  ...    ...   ...    ...     ...                     ...   ...
# 85  2020-01-04    4      1  2020      0       0             Afghanistan    AF
# 86  2020-01-03    3      1  2020      0       0             Afghanistan    AF
# 87  2020-01-02    2      1  2020      0       0             Afghanistan    AF
# 88  2020-01-01    1      1  2020      0       0             Afghanistan    AF
# 89  2019-12-31   31     12  2019      0       0             Afghanistan    AF
#
# ...

# %% [markdown]
# ## Total number of deaths in the country afghanistan

# %%
afg['deaths'].sum()
# Out:
# 11

# %% [markdown]
# ## Number of deaths per years in afghanistan using line plot

# %%
import matplotlib.pyplot as plt

# %%
afg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 0 to 89
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dateRep                  90 non-null     object
#  1   day                      90 non-null     int64
#  2   month                    90 non-null     int64
#  3   year                     90 non-null     int64
#  4   cases                    90 non-null     int64
#  5   deaths                   90 non-null     int64
#  6   countriesAndTerritories  90 non-null     object
#  7   geoId                    90 non-null     object
#  8   countryterritoryCode     90 non-null     object
#  9   popData2018              90 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 7.7+ KB

# %%
afg['year'].unique()
# Out:
# array([2020, 2019])

# %%
plt.plot(afg['year'],afg['deaths'],marker='o',color='r')
plt.xlabel('year')
plt.ylabel('deaths')
plt.title('deaths per year');

# %%
covid['countriesAndTerritories'].nunique()
# Out:
# 204

# %%
covid['countriesAndTerritories'].value_counts()
# Out:
# countriesAndTerritories
# Italy                                100
# Belgium                              100
# China                                100
# Canada                               100
# Czechia                              100
#                                     ...
# Sierra_Leone                           8
# Bonaire, Saint Eustatius and Saba      7
# Malawi                                 6
# Falkland_Islands_(Malvinas)            5
# South_Sudan                            3
# Name: count, Length: 204, dtype: int64

# %% [markdown]
# ## deaths over cases in first 20 countries

# %%
country.head(1)
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-04-08    8      4  2020     30       4             Afghanistan
# 90    2020-04-08    8      4  2020      6       0                 Albania
# 121   2020-04-08    8      4  2020     19       1                 Andorra
# 128   2020-04-08    8      4  2020     45      21                 Algeria
# 242   2020-04-08    8      4  2020      1       0                  Angola
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9328  2020-04-08    8      4  2020    107       0              Uzbekistan
# 9352  2020-04-08    8      4  2020      7       2               Venezuela
# 9377  2020-04-08    8      4  2020      6       0                 Vietnam
# 9473  2020-04-08    8      4  2020      0       0                  Zambia
# 9494  2020-04-08    8      4  2020      1       0                Zimbabwe
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
first20=country.sum(numeric_only=True).head(20)

# %%
first20
# Out:
#                           day  month    year  cases  deaths   popData2018
# countriesAndTerritories
# Afghanistan              1411    196  181799    367      11  3.345515e+09
# Albania                   496    101   62620    383      22  8.885766e+07
# Algeria                  1455    211  191899   1468     194  4.011701e+09
# Andorra                   429     86   52520    545      22  2.002156e+06
# Angola                    301     62   36360     17       2  5.545757e+08
# Anguilla                  181     47   26260      3       0  0.000000e+00
# Antigua_and_Barbuda       337     68   40400     15       0  1.925720e+06
# Argentina                 499    107   66660   1715      60  1.468319e+09
# Armenia                  1431    199  183819    853       8  2.686116e+08
# Aruba                     258     59   34340     74       0  1.799365e+06
# Australia                1494    226  201999   5956      45  2.499237e+09
# ...

# %%
plt.plot(first20['cases'],first20['deaths'],marker='o')
plt.xlabel('cases')
plt.ylabel('deaths')
plt.title('deaths over cases');

# %%
plt.bar(first20['cases'],first20['deaths'],color='r',edgecolor='black')
plt.xlabel('cases')
plt.ylabel('deaths')
plt.title('deaths over cases');

# %%
a=first20[['cases','deaths']]

# %%
a
# Out:
#                          cases  deaths
# countriesAndTerritories
# Afghanistan                367      11
# Albania                    383      22
# Algeria                   1468     194
# Andorra                    545      22
# Angola                      17       2
# Anguilla                     3       0
# Antigua_and_Barbuda         15       0
# Argentina                 1715      60
# Armenia                    853       8
# Aruba                       74       0
# Australia                 5956      45
# Austria                  12640     243
# Azerbaijan                 717       8
# Bahamas                     36       6
# Bahrain                    811       5
# Bangladesh                 164      17
# Barbados                    63       3
# Belarus                    861      13
# Belgium                  22194    2035
# Belize                       7       1

# %%
a.plot(kind='line',colormap='plasma',figsize=(8,6),marker='o')
plt.xlabel('cases')
plt.ylabel('deaths')
plt.title('deaths over cases');

# %%
a.plot(kind='bar',colormap='plasma',edgecolor='black',stacked=True)
plt.xlabel('cases')
plt.ylabel('deaths')
plt.title('deaths over cases');

# %%
a.plot(kind='hist',colormap='plasma');

# %%
a.hist(bins=10,edgecolor='black',color='r')
plt.suptitle('cases and deaths rate')
plt.grid(False);

# %%
plt.boxplot([first20['cases'],first20['deaths']]);

# %%
a.boxplot(labels=a.columns);

# %%
plt.violinplot([first20['cases'],first20['deaths']])
plt.xlabel('cases')
plt.ylabel('deaths')
plt.title('cases and deaths rate');

# %% [markdown]
# ## total deaths in the year 2019

# %%
covid
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-04-08    8      4  2020     30       4             Afghanistan
# 1     2020-04-07    7      4  2020     38       0             Afghanistan
# 2     2020-04-06    6      4  2020     29       2             Afghanistan
# 3     2020-04-05    5      4  2020     35       1             Afghanistan
# 4     2020-04-04    4      4  2020      0       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9508  2020-03-25   25      3  2020      0       0                Zimbabwe
# 9509  2020-03-24   24      3  2020      0       1                Zimbabwe
# 9510  2020-03-23   23      3  2020      0       0                Zimbabwe
# 9511  2020-03-22   22      3  2020      1       0                Zimbabwe
# 9512  2020-03-21   21      3  2020      1       0                Zimbabwe
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
covid['year'].unique()
# Out:
# array([2020, 2019])

# %%
yr2019=covid.groupby('year').get_group(2019)

# %%
yr2019
# Out:
#          dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 89    2019-12-31   31     12  2019      0       0               Afghanistan
# 222   2019-12-31   31     12  2019      0       0                   Algeria
# 416   2019-12-31   31     12  2019      0       0                   Armenia
# 533   2019-12-31   31     12  2019      0       0                 Australia
# 633   2019-12-31   31     12  2019      0       0                   Austria
# ...          ...  ...    ...   ...    ...     ...                       ...
# 8783  2019-12-31   31     12  2019      0       0                  Thailand
# 9064  2019-12-31   31     12  2019      0       0      United_Arab_Emirates
# 9164  2019-12-31   31     12  2019      0       0            United_Kingdom
# 9287  2019-12-31   31     12  2019      0       0  United_States_of_America
# 9472  2019-12-31   31     12  2019      0       0                   Vietnam
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
yr2019['deaths'].sum()
# Out:
# 0

# %% [markdown]
# ## total deaths in the year 2020

# %%
yr2020=covid.groupby('year').get_group(2020)

# %%
yr2020
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-04-08    8      4  2020     30       4             Afghanistan
# 1     2020-04-07    7      4  2020     38       0             Afghanistan
# 2     2020-04-06    6      4  2020     29       2             Afghanistan
# 3     2020-04-05    5      4  2020     35       1             Afghanistan
# 4     2020-04-04    4      4  2020      0       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9508  2020-03-25   25      3  2020      0       0                Zimbabwe
# 9509  2020-03-24   24      3  2020      0       1                Zimbabwe
# 9510  2020-03-23   23      3  2020      0       0                Zimbabwe
# 9511  2020-03-22   22      3  2020      1       0                Zimbabwe
# 9512  2020-03-21   21      3  2020      1       0                Zimbabwe
#
#      geoId countryterritoryCode  popData2018
# ...

# %%
yr2020['deaths'].sum()
# Out:
# 81478

# %% [markdown]
# ## how many cases are reported in april 2020

# %%
covid.groupby('month').get_group(4)
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-04-08    8      4  2020     30       4             Afghanistan
# 1     2020-04-07    7      4  2020     38       0             Afghanistan
# 2     2020-04-06    6      4  2020     29       2             Afghanistan
# 3     2020-04-05    5      4  2020     35       1             Afghanistan
# 4     2020-04-04    4      4  2020      0       0             Afghanistan
# ...          ...  ...    ...   ...    ...     ...                     ...
# 9497  2020-04-05    5      4  2020      0       0                Zimbabwe
# 9498  2020-04-04    4      4  2020      1       0                Zimbabwe
# 9499  2020-04-03    3      4  2020      0       0                Zimbabwe
# 9500  2020-04-02    2      4  2020      0       0                Zimbabwe
# 9501  2020-04-01    1      4  2020      1       0                Zimbabwe
#
#      geoId countryterritoryCode  popData2018
# ...
