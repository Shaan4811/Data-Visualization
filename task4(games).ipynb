# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
games=pd.read_csv('/Users/shaan/Desktop/data analytics/Matplotlib/docs/Online_game.csv')

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Description

# %% [markdown]
#     * This dataset appears to represent video game sales data, containing information about 16,598 video games.
#     * Each row corresponds to a specific video game, and the dataset includes the following columns:
#
#     * Rank: A unique integer identifier that ranks the video games based on a specific criterion (likely sales).
#     * Name: The name of the video game.
#     * Platform: The gaming platform on which the video game was released (e.g., PS4, Xbox One, PC).
#     * Year: The year the
#       game was released. This column has some missing values, with 16,327 non-null entries out of 16,598.
#     * Genre: The genre of the video game (e.g., Action, Sports, RPG).
#     * Publisher: The company that published the video game. There are a few missing values, with 16,540 non-null entries.
#     * NA_Sales: Sales in North America, measured in millions of units.
#     * EU_Sales: Sales in Europe, measured in millions of units.
#     * JP_Sales: Sales in Japan, measured in millions of units.
#     * Other_Sales: Sales in regions other than North America, Europe, and Japan, measured in millions of units.
#     * Global_Sales: The total global sales of the video game, measured in millions of units.

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
  # There is some null values so either we use drop or use fillna method

# %%
games.fillna(0,inplace=True)

# %%
games.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
games.duplicated().sum()
# Out:
# 0

# %%
games.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   1973.647307      0.264667      0.146652      0.077782
# std     4791.853933    254.346809      0.816683      0.505351      0.309291
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
games.describe().T
# Out:
#                 count         mean          std   min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933  1.00  4151.25  8300.50
# Year          16598.0  1973.647307   254.346809  0.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683  0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351  0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291  0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588  0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028  0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %% [markdown]
# ## q1 retrieve the full details of the publisher 'Nintendo'

# %%
games['Publisher'].nunique()
# Out:
# 579

# %%
nint=games[games['Publisher']=='Nintendo']

# %%
nint
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## q2 retrieve all the games that are published by the publisher 'Nintendo' and the year

# %%
nint[['Name','Year']]
# Out:
#                                                     Name    Year
# 0                                             Wii Sports  2006.0
# 1                                      Super Mario Bros.  1985.0
# 2                                         Mario Kart Wii  2008.0
# 3                                      Wii Sports Resort  2009.0
# 4                               Pokemon Red/Pokemon Blue  1996.0
# ...                                                  ...     ...
# 16269                           Slide Adventure: Mag Kid  2007.0
# 16357               Mario vs. Donkey Kong: Tipping Stars  2015.0
# 16456                           Art Academy: Home Studio  2015.0
# 16473                                    Captain Rainbow  2008.0
# 16542  Mario & Luigi: Paper Jam & Mario Kart 7 Double...  2015.0
#
# [703 rows x 2 columns]

# %% [markdown]
# ## q3 the publisher with high global sale

# %%
games.groupby(['Publisher'])['Global_Sales'].max().sort_values(ascending=False).idxmax()
# Out:
# 'Nintendo'

# %% [markdown]
# ## q4 in which region the publisher nintendo has high sales(north amnerica,europe,japan)

# %%
nintendo=games.groupby('Publisher')

# %%
nintendo=nintendo.get_group('Nintendo')

# %%
nintendo[['NA_Sales','EU_Sales','JP_Sales']].max()
# Out:
# NA_Sales    41.49
# EU_Sales    29.02
# JP_Sales    10.22
# dtype: float64

# %%
nintendo[['NA_Sales','EU_Sales','JP_Sales']].max().idxmax()
# Out:
# 'NA_Sales'

# %% [markdown]
# ## q5 retrieve the game with high global sale in 2010

# %%
games['Year']=games['Year'].astype('int64')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16598 non-null  int64
#  4   Genre         16598 non-null  object
#  5   Publisher     16598 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
year=games.groupby('Year')

# %%
year

# %%
yr2010=year.get_group(2010)

# %%
yr2010
# Out:
#         Rank                                               Name Platform  \
# 15        16                                 Kinect Adventures!     X360
# 26        27                        Pokemon Black/Pokemon White       DS
# 31        32                            Call of Duty: Black Ops     X360
# 40        41                            Call of Duty: Black Ops      PS3
# 54        55                                     Gran Turismo 5      PS3
# ...      ...                                                ...      ...
# 16437  16440              The Cages: Pro Style Batting Practice      Wii
# 16478  16481                 Ishin no Arashi: Shippuu Ryuumeden       DS
# 16487  16490          Slotter Mania P: Tetsuya Shinjuku vs Ueno      PSP
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16596  16599                                         Know How 2       DS
#
#        Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
top=yr2010.groupby('Name')

# %%
top

# %%
top['Global_Sales'].max().sort_values(ascending=False).idxmax()
# Out:
# 'Kinect Adventures!'

# %% [markdown]
# ## q6 retrieve the highest rank of the game with genre in sports

# %%
sprts=games.groupby('Genre')

# %%
sprts=sprts.get_group('Sports')

# %%
sprts
# Out:
#         Rank                           Name Platform  Year   Genre  \
# 0          1                     Wii Sports      Wii  2006  Sports
# 3          4              Wii Sports Resort      Wii  2009  Sports
# 13        14                        Wii Fit      Wii  2007  Sports
# 14        15                   Wii Fit Plus      Wii  2009  Sports
# 77        78                        FIFA 16      PS4  2015  Sports
# ...      ...                            ...      ...   ...     ...
# 16576  16579              Rugby Challenge 3     XOne  2016  Sports
# 16578  16581  Outdoors Unleashed: Africa 3D      3DS  2011  Sports
# 16579  16582              PGA European Tour      N64  2000  Sports
# 16581  16584                      Fit & Fun      Wii  2011  Sports
# 16587  16590       Mezase!! Tsuri Master DS       DS  2009  Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                  Nintendo     41.49     29.02      3.77         8.46
# ...

# %%
sprts[['Rank','Name']].iloc[0]
# Out:
# Rank             1
# Name    Wii Sports
# Name: 0, dtype: object

# %% [markdown]
# ## q7 retrieve the game with highest global sale with genre in racing

# %%
rac=games.groupby('Genre')

# %%
rac

# %%
racing=rac.get_group('Racing')

# %%
racing
# Out:
#         Rank                                               Name Platform  \
# 2          3                                     Mario Kart Wii      Wii
# 11        12                                      Mario Kart DS       DS
# 28        29                             Gran Turismo 3: A-Spec      PS2
# 42        43                                       Mario Kart 7      3DS
# 47        48                                     Gran Turismo 4      PS2
# ...      ...                                                ...      ...
# 16530  16533                           Sébastien Loeb Rally Evo     XOne
# 16543  16546                             Driving Simulator 2011       PC
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
#
#        Year   Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
racing[['Global_Sales','Name']]
# Out:
#        Global_Sales                                               Name
# 2             35.82                                     Mario Kart Wii
# 11            23.42                                      Mario Kart DS
# 28            14.98                             Gran Turismo 3: A-Spec
# 42            12.21                                       Mario Kart 7
# 47            11.66                                     Gran Turismo 4
# ...             ...                                                ...
# 16530          0.01                           Sébastien Loeb Rally Evo
# 16543          0.01                             Driving Simulator 2011
# 16573          0.01                                Mini Desktop Racing
# 16574          0.01  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...
# 16595          0.01   SCORE International Baja 1000: The Official Game
#
# [1249 rows x 2 columns]

# %%
racing[['Global_Sales','Name']].head(1)
# Out:
#    Global_Sales            Name
# 2         35.82  Mario Kart Wii

# %% [markdown]
# ## q8 what is the average global sale of the publisher nintendo with genre in racing

# %%
games
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %%
game=games.groupby('Publisher')

# %%
ninte=game.get_group('Nintendo')

# %%
ninte
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#        Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
rac=ninte.groupby('Genre')

# %%
rac=rac.get_group('Racing')

# %%
rac
# Out:
#         Rank                                     Name Platform  Year   Genre  \
# 2          3                           Mario Kart Wii      Wii  2008  Racing
# 11        12                            Mario Kart DS       DS  2005  Racing
# 42        43                             Mario Kart 7      3DS  2011  Racing
# 63        64                            Mario Kart 64      N64  1996  Racing
# 76        77                         Super Mario Kart     SNES  1992  Racing
# 108      109                             Mario Kart 8     WiiU  2014  Racing
# 110      111                Mario Kart: Double Dash!!       GC  2003  Racing
# 163      164                Mario Kart: Super Circuit      GBA  2001  Racing
# 213      214                        Diddy Kong Racing      N64  1997  Racing
# 277      278                               Excitebike      NES  1984  Racing
# 391      392                                 F-1 Race       GB  1990  Racing
# ...

# %%
rac['Global_Sales'].mean()
# Out:
# 4.08918918918919

# %% [markdown]
# ## q9 top 10 games of the publisher nintendos with high global sales and its years

# %%
ninte
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#        Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
top10=ninte.nlargest(10,'Global_Sales')[['Name','Year','Global_Sales']]

# %%
top10
# Out:
#                         Name  Year  Global_Sales
# 0                 Wii Sports  2006         82.74
# 1          Super Mario Bros.  1985         40.24
# 2             Mario Kart Wii  2008         35.82
# 3          Wii Sports Resort  2009         33.00
# 4   Pokemon Red/Pokemon Blue  1996         31.37
# 5                     Tetris  1989         30.26
# 6      New Super Mario Bros.  2006         30.01
# 7                   Wii Play  2006         29.02
# 8  New Super Mario Bros. Wii  2009         28.62
# 9                  Duck Hunt  1984         28.31

# %%
plt.bar(top10['Year'],top10['Global_Sales'])
plt.xlabel('year')
plt.ylabel('global sales')
plt.title('top 10 global sale');

# %% [markdown]
# ## q10 which game has the lowest global sale and retrieve a plot regarding  10 games with lowest global sale and the years

# %%
low=games.nsmallest(10,'Global_Sales')[['Name','Year','Global_Sales']]

# %%
low
# Out:
#                                                     Name  Year  Global_Sales
# 15980                                              Turok  2008          0.01
# 15981                     Coven and Labyrinth of Refrain  2016          0.01
# 15982  Super Battle For Money Sentouchuu: Kyuukyoku n...  2016          0.01
# 15983                                   Dragon Zakura DS  2007          0.01
# 15984                             Chameleon: To Dye For!  2006          0.01
# 15985                                     Hotel Giant DS  2008          0.01
# 15986       Sora no Otoshimono: DokiDoki Summer Vacation  2010          0.01
# 15987                                        Blackthorne  2003          0.01
# 15988                             Don Bradman Cricket 14  2014          0.01
# 15989                         DokuSui: DokiDoki Suikoden  2011          0.01

# %%
games['Global_Sales'].min()
# Out:
# 0.01

# %%
plt.plot(low['Global_Sales'],low['Year'])
plt.xlabel('sale')
plt.ylabel('year');

# %% [markdown]
# ## q11 which publishers game has the high sale in north america

# %%
games
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %%
games['NA_Sales'].max()
# Out:
# 41.49

# %%
games[['NA_Sales','Name','Genre']].head(1)
# Out:
#    NA_Sales        Name   Genre
# 0     41.49  Wii Sports  Sports

# %% [markdown]
# ## q12top 10 games with high sale in japan and the year of production

# %%
games[['Name','Year','JP_Sales']].nlargest(10,'JP_Sales')
# Out:
#                                             Name  Year  JP_Sales
# 4                       Pokemon Red/Pokemon Blue  1996     10.22
# 12                   Pokemon Gold/Pokemon Silver  1999      7.20
# 1                              Super Mario Bros.  1985      6.81
# 6                          New Super Mario Bros.  2006      6.50
# 20                 Pokemon Diamond/Pokemon Pearl  2006      6.04
# 26                   Pokemon Black/Pokemon White  2010      5.65
# 25                 Pokemon Ruby/Pokemon Sapphire  2002      5.38
# 41                   Animal Crossing: Wild World  2005      5.33
# 27   Brain Age 2: More Training in Minutes a Day  2005      5.32
# 214                     Monster Hunter Freedom 3  2010      4.87

# %% [markdown]
# ## q13 retrieve the games that comes under the platform wii

# %%
pla=games.groupby('Platform')

# %%
pla=pla.get_group('Wii')

# %%
pla['Name']
# Out:
# 0                                               Wii Sports
# 2                                           Mario Kart Wii
# 3                                        Wii Sports Resort
# 7                                                 Wii Play
# 8                                New Super Mario Bros. Wii
#                                ...
# 16517                         Teenage Mutant Ninja Turtles
# 16552             Mahou Sensei Negima!? Neo-Pactio Fight!!
# 16573                                  Mini Desktop Racing
# 16574    Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...
# 16581                                            Fit & Fun
# Name: Name, Length: 1325, dtype: object

# %% [markdown]
# ## q14 retrieve the game with japan sale=10.22

# %%
games[games['JP_Sales']==10.22]['Name']
# Out:
# 4    Pokemon Red/Pokemon Blue
# Name: Name, dtype: object

# %% [markdown]
# ## q15 calculate  the mean of north american sale,median of europe sale and sum of japan sale

# %%
games[['NA_Sales','EU_Sales','JP_Sales']].agg(['mean','median','sum'])
# Out:
#            NA_Sales     EU_Sales     JP_Sales
# mean       0.264667     0.146652     0.077782
# median     0.080000     0.020000     0.000000
# sum     4392.950000  2434.130000  1291.020000
