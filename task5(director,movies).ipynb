# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
director=pd.read_csv('/Users/shaan/Desktop/data analytics/Matplotlib/docs/directors.csv')

# %%
director
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
movies=pd.read_csv('/Users/shaan/Desktop/data analytics/Matplotlib/docs/movies.csv')

# %%
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %% [markdown]
# ## Merging two data sets using left joins

# %%
movdir=movies.merge(director,how='left',left_on='director_id',right_on='id')

# %%
movdir
# Out:
#       Unnamed: 0_x   id_x     budget  popularity     revenue  \
# 0                0  43597  237000000         150  2787965087
# 1                1  43598  300000000         139   961000000
# 2                2  43599  245000000         107   880674609
# 3                3  43600  250000000         112  1084939099
# 4                5  43602  258000000         115   890871626
# ...            ...    ...        ...         ...         ...
# 1460          4736  48363          0           3      321952
# 1461          4743  48370      27000          19     3151130
# 1462          4748  48375          0           7           0
# 1463          4749  48376          0           3           0
# 1464          4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
movdir.columns
# Out:
# Index(['Unnamed: 0_x', 'id_x', 'budget', 'popularity', 'revenue', 'title',
#        'vote_average', 'vote_count', 'director_id', 'year', 'month', 'day',
#        'Unnamed: 0_y', 'director_name', 'id_y', 'gender'],
#       dtype='object')

# %%
# dropping duplicates columns

# %%
movdir.drop(columns=['Unnamed: 0_x','id_y','Unnamed: 0_y'],axis=1,inplace=True)

# %%
movdir
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
# renaming column names

# %%
movdir.rename(columns={'id_x':'id'},inplace=True)

# %%
movdir
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
movdir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   director_id    1465 non-null   int64
#  8   year           1465 non-null   int64
#  9   month          1465 non-null   object
#  10  day            1465 non-null   object
#  11  director_name  1465 non-null   object
#  12  gender         1341 non-null   object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 148.9+ KB

# %%
# checking null values

# %%
movdir.isnull().sum()
# Out:
# id                 0
# budget             0
# popularity         0
# revenue            0
# title              0
# vote_average       0
# vote_count         0
# director_id        0
# year               0
# month              0
# day                0
# director_name      0
# gender           124
# dtype: int64

# %%
# dropping nulll values

# %%
movdir.dropna(inplace=True)

# %%
movdir.isnull().sum()
# Out:
# id               0
# budget           0
# popularity       0
# revenue          0
# title            0
# vote_average     0
# vote_count       0
# director_id      0
# year             0
# month            0
# day              0
# director_name    0
# gender           0
# dtype: int64

# %% [markdown]
# ## Description

# %%
# Unnamed: 0: Likely an index column or a redundant ID column.
# id: The unique identifier for each movie or data entry.
# budget: The allocated budget for the movie, likely in millions.
# popularity: A measure of how popular the movie is, based on factors like views, mentions, etc.
# revenue: The total earnings or revenue the movie generated, possibly in millions.
# title: The title or name of the movie.
# vote_average: The average rating the movie received, usually out of 10 (scaled to 100 here).
# vote_count: The number of people who voted or rated the movie.
# director_id: The unique identifier for the movie's director.
# year: The year the movie was released or produced.
# month: The month the movie was released or produced.
# day: The day of the month the movie was released or produced.

# %%
# checking duplicates if any

# %%
movdir.duplicated().sum()
# Out:
# 0

# %%
# finding aggregrates of the numerical

# %%
movdir.describe().T
# Out:
#                count          mean           std      min         25%  \
# id            1341.0  4.519527e+04  1.191463e+03  43597.0     44192.0
# budget        1341.0  4.929728e+07  4.997809e+07      0.0  15000000.0
# popularity    1341.0  3.146682e+01  3.559951e+01      0.0        12.0
# revenue       1341.0  1.477889e+08  2.113013e+08      0.0  18928871.0
# vote_average  1341.0  6.378896e+00  8.165055e-01      3.0         5.9
# vote_count    1341.0  1.184343e+03  1.614749e+03      1.0       226.0
# director_id   1341.0  5.031985e+03  2.541864e+02   4762.0      4842.0
# year          1341.0  2.002587e+03  8.688950e+00   1976.0      1998.0
#
#                      50%          75%           max
# id               44973.0      45959.0  4.837600e+04
# budget        35000000.0   70000000.0  3.800000e+08
# popularity          23.0         41.0  7.240000e+02
# revenue       80049764.0  183953723.0  2.787965e+09
# vote_average         6.4          7.0  8.300000e+00
# ...

# %%
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %% [markdown]
# ## q1: retrieve which movie has the highest revenue and list top 10 highest revenue genrated movies

# %%
movdir['revenue'].max()
# Out:
# 2787965087

# %%
revenue=movdir.sort_values(by='revenue',ascending=False).reset_index(drop=True).head(10)

# %%
revenue
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43622  200000000         100  1845034188
# 2  43641  190000000         102  1506249360
# 3  43649  195000000          28  1123746996
# 4  43926   94000000         123  1118888979
# 5  43626  200000000          93  1108561013
# 6  43633  210000000         116  1091405097
# 7  43600  250000000         112  1084939099
# 8  43609  200000000         145  1065659812
# 9  43614  380000000         135  1045713802
#
#                                            title  vote_average  vote_count  \
# 0                                         Avatar           7.2       11800
# 1                                        Titanic           7.5        7562
# 2                                      Furious 7           7.3        4176
# 3                 Transformers: Dark of the Moon           6.1        3299
# 4  The Lord of the Rings: The Return of the King           8.1        8064
# ...

# %%
top10revenue=revenue[['title','revenue']]

# %%
top10revenue
# Out:
#                                            title     revenue
# 0                                         Avatar  2787965087
# 1                                        Titanic  1845034188
# 2                                      Furious 7  1506249360
# 3                 Transformers: Dark of the Moon  1123746996
# 4  The Lord of the Rings: The Return of the King  1118888979
# 5                                        Skyfall  1108561013
# 6                Transformers: Age of Extinction  1091405097
# 7                          The Dark Knight Rises  1084939099
# 8     Pirates of the Caribbean: Dead Man's Chest  1065659812
# 9    Pirates of the Caribbean: On Stranger Tides  1045713802

# %%
plt.figure(figsize=(10,5))
plt.plot(top10revenue['title'],top10revenue['revenue'],marker='o',c='r')
plt.xticks(rotation=90)
plt.xlabel('Name')
plt.ylabel('Revenues')
plt.grid(True)
plt.title('Top 10 revenue generating movies');

# %% [markdown]
# ## q2 Retrieve top 10 budgetted movies and the rating of that movies

# %%
budget=movdir.nlargest(10,'budget')[['title','budget','vote_average']].reset_index()

# %%
budget
# Out:
#    index                                        title     budget  vote_average
# 0     12  Pirates of the Caribbean: On Stranger Tides  380000000           6.4
# 1      1     Pirates of the Caribbean: At World's End  300000000           6.9
# 2      6                             Superman Returns  270000000           5.4
# 3      4                                 Spider-Man 3  258000000           5.9
# 4      9                              The Lone Ranger  255000000           5.9
# 5      3                        The Dark Knight Rises  250000000           7.6
# 6      5           Batman v Superman: Dawn of Justice  250000000           5.7
# 7     14    The Hobbit: The Battle of the Five Armies  250000000           7.1
# 8     16          The Hobbit: The Desolation of Smaug  250000000           7.6
# 9     32                   X-Men: Days of Future Past  250000000           7.5

# %% [markdown]
# ## q3 Which movies are released during year ends and the years

# %%
movdir[movdir['month']=='Dec']
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 14    43616  250000000         120   956019788
# 16    43619  250000000          94   958400000
# 18    43621  207000000          61   550000000
# 43    43660  180000000          67   748806957
# ...     ...        ...         ...         ...
# 1378  47387          0           0           0
# 1383  47453    3500000           4           0
# 1390  47491    3000000           7    20966644
# 1403  47674    2000000          37    24600832
# 1452  48274          0           5     2611555
#
#                                                   title  vote_average  \
# 0                                                Avatar           7.2
# 14            The Hobbit: The Battle of the Five Armies           7.1
# 16                  The Hobbit: The Desolation of Smaug           7.6
# 18                                            King Kong           6.6
# ...

# %%
dec=movdir.groupby('month').get_group('Dec')

# %%
dec
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 14    43616  250000000         120   956019788
# 16    43619  250000000          94   958400000
# 18    43621  207000000          61   550000000
# 43    43660  180000000          67   748806957
# ...     ...        ...         ...         ...
# 1378  47387          0           0           0
# 1383  47453    3500000           4           0
# 1390  47491    3000000           7    20966644
# 1403  47674    2000000          37    24600832
# 1452  48274          0           5     2611555
#
#                                                   title  vote_average  \
# 0                                                Avatar           7.2
# 14            The Hobbit: The Battle of the Five Armies           7.1
# 16                  The Hobbit: The Desolation of Smaug           7.6
# 18                                            King Kong           6.6
# ...

# %%
dec[['title','month','year']].reset_index(drop=True)
# Out:
#                                                  title month  year
# 0                                               Avatar   Dec  2009
# 1            The Hobbit: The Battle of the Five Armies   Dec  2014
# 2                  The Hobbit: The Desolation of Smaug   Dec  2013
# 3                                            King Kong   Dec  2005
# 4    The Chronicles of Narnia: The Lion, the Witch ...   Dec  2005
# ..                                                 ...   ...   ...
# 175                               An Everlasting Piece   Dec  2000
# 176                        In the Name of the King III   Dec  2013
# 177                                 A Room with a View   Dec  1985
# 178                        Mad Max 2: The Road Warrior   Dec  1981
# 179                                              Three   Dec  2010
#
# [180 rows x 3 columns]

# %% [markdown]
# ## q4 list top 10 popular movies and the revenues generated by that movies

# %%
# method1

# %%
movdir[['title','revenue','popularity']].sort_values(by='popularity',ascending=False).head(10).reset_index(drop=True)
# Out:
#                                                title     revenue  popularity
# 0                                       Interstellar   675120017         724
# 1                                 Mad Max: Fury Road   378858340         434
# 2  Pirates of the Caribbean: The Curse of the Bla...   655011224         271
# 3              The Hunger Games: Mockingjay - Part 1   752100229         206
# 4                                    The Dark Knight  1004558444         187
# 5                                        The Martian   630161890         167
# 6                                          Inception   825532764         167
# 7                 Batman v Superman: Dawn of Justice   873260194         155
# 8                                             Avatar  2787965087         150
# 9                                         Fight Club   100853753         146

# %%
# method2

# %%
movdir.sort_values(by='popularity',ascending=False)[['title','revenue','popularity']].head(10)
# Out:
#                                                  title     revenue  popularity
# 58                                        Interstellar   675120017         724
# 78                                  Mad Max: Fury Road   378858340         434
# 119  Pirates of the Caribbean: The Curse of the Bla...   655011224         271
# 120              The Hunger Games: Mockingjay - Part 1   752100229         206
# 45                                     The Dark Knight  1004558444         187
# 162                                        The Martian   630161890         167
# 59                                           Inception   825532764         167
# 5                   Batman v Superman: Dawn of Justice   873260194         155
# 0                                               Avatar  2787965087         150
# 383                                         Fight Club   100853753         146

# %%
# method3

# %%
top10popular=movdir.nlargest(10,'popularity')[['title','revenue','popularity']].reset_index(drop=True)

# %%
top10popular
# Out:
#                                                title     revenue  popularity
# 0                                       Interstellar   675120017         724
# 1                                 Mad Max: Fury Road   378858340         434
# 2  Pirates of the Caribbean: The Curse of the Bla...   655011224         271
# 3              The Hunger Games: Mockingjay - Part 1   752100229         206
# 4                                    The Dark Knight  1004558444         187
# 5                                          Inception   825532764         167
# 6                                        The Martian   630161890         167
# 7                 Batman v Superman: Dawn of Justice   873260194         155
# 8                                             Avatar  2787965087         150
# 9                                         Fight Club   100853753         146

# %%
movdir.groupby('title')['popularity'].max().sort_values(ascending=False).head().plot(kind='pie',explode=(0,0,0,0,0.1),shadow=True,autopct="%1.1f%%");

# %%
to=top10popular.set_index('title')

# %%
to
# Out:
#                                                        revenue  popularity
# title
# Interstellar                                         675120017         724
# Mad Max: Fury Road                                   378858340         434
# Pirates of the Caribbean: The Curse of the Blac...   655011224         271
# The Hunger Games: Mockingjay - Part 1                752100229         206
# The Dark Knight                                     1004558444         187
# Inception                                            825532764         167
# The Martian                                          630161890         167
# Batman v Superman: Dawn of Justice                   873260194         155
# Avatar                                              2787965087         150
# Fight Club                                           100853753         146

# %%
to.plot(kind='line',colormap='viridis',xlabel='movies',ylabel='reve')
plt.xticks(rotation=90);

# %%
to.plot(kind='bar',colormap='viridis',xlabel='movies',ylabel='reve')
plt.xticks(rotation=90);

# %% [markdown]
# ## q5 list top 10 rating movies released on fridays

# %%
fri=movdir.groupby('day').get_group('Friday')

# %%
fri
# Out:
#          id     budget  popularity    revenue  \
# 22    43627  200000000          35  783766341
# 25    43632  150000000          21  836297228
# 61    43696   38000000           6  207283925
# 65    43701  160000000          21  181674817
# 66    43706  155000000          49  415686217
# ...     ...        ...         ...        ...
# 1455  48310     160000           3    6706368
# 1457  48323          0           5          0
# 1458  48335      60000          27    3221152
# 1462  48375          0           7          0
# 1463  48376          0           3          0
#
#                                                   title  vote_average  \
# 22                                         Spider-Man 2           6.7
# 25                  Transformers: Revenge of the Fallen           6.0
# 61                             The Fast and the Furious           6.6
# 65                                             Poseidon           5.5
# ...

# %%
fri.nlargest(10,'vote_average')[['title','day','vote_average']].reset_index(drop=True)
# Out:
#                       title     day  vote_average
# 0                Fight Club  Friday           8.3
# 1                     Se7en  Friday           8.1
# 2  The Silence of the Lambs  Friday           8.1
# 3       Saving Private Ryan  Friday           7.9
# 4              Blade Runner  Friday           7.9
# 5       There Will Be Blood  Friday           7.9
# 6         Good Will Hunting  Friday           7.9
# 7                     Alien  Friday           7.9
# 8       Requiem for a Dream  Friday           7.9
# 9                 The Thing  Friday           7.8

# %%
movdir
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1459  48359          0           2           0
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# ## q6 list top 10 low budget movies and the rating of the movies

# %%
movdir.nsmallest(100,'budget')[['budget','vote_average','title']]
# Out:
#       budget  vote_average                            title
# 195        0           5.6                     The Campaign
# 271        0           5.6                 The Pink Panther
# 281        0           6.7                         The Edge
# 341        0           6.0                             Wolf
# 435        0           5.1  Garfield: A Tail of Two Kitties
# ...      ...           ...                              ...
# 1412       0           5.4                            Plush
# 1413       0           5.9                 Slacker Uprising
# 1414       0           6.7                        Northfork
# 1416       0           6.5                          Exotica
# 1418       0           6.5                      Snow Angels
#
# [100 rows x 3 columns]

# %% [markdown]
# ## q7 the overalll budget the film industry made in the year 2000

# %%
yr2000=movdir.groupby('year').get_group(2000)

# %%
yr2000
# Out:
#          id     budget  popularity    revenue  \
# 129   43808  123000000          45  345141403
# 131   43810  125000000          54  546388105
# 132   43811  120000000          25  325756637
# 146   43843  110000000          23  215294342
# 165   43871  103000000          95  457640427
# 208   43943  100000000          15  155464351
# 210   43947   92000000          40  264105545
# 222   43963   95000000          28  190213455
# 228   43970   90000000          16   60874615
# 232   43981   90000000          57  429632142
# 247   44010   84000000          17  123307945
# 282   44074   80000000          18   34566746
# 297   44108   75000000           4  296339527
# 305   44120   75000000          13  215663859
# 316   44142   75000000          42  248118121
# 361   44227   70000000          31  374111707
# 369   44240   65000000          15  128884132
# 372   44243   65000000          18   69700000
# 405   44307   60000000          19          0
# ...

# %%
yr2000['budget'].sum()
# Out:
# 2714500000

# %% [markdown]
# ## q8 list all the movies of the director James Cameron and popularity of the movies

# %%
di=movdir.groupby('director_name').get_group('James Cameron')

# %%
di
# Out:
#          id     budget  popularity     revenue                       title  \
# 0     43597  237000000         150  2787965087                      Avatar
# 19    43622  200000000         100  1845034188                     Titanic
# 170   43876  100000000         101   520000000  Terminator 2: Judgment Day
# 173   43879  115000000          38   378882411                   True Lies
# 344   44184   70000000          24    90000098                   The Abyss
# 1100  46000   18500000          67   183316455                      Aliens
# 1320  47036    6400000          74    78371200              The Terminator
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# 19             7.5        7562         4762  1997   Nov    Tuesday
# 170            7.7        4185         4762  1991   Jul     Monday
# 173            6.8        1116         4762  1994   Jul   Thursday
# ...

# %%
di[['title','director_name','popularity']].reset_index(drop=True)
# Out:
#                         title  director_name  popularity
# 0                      Avatar  James Cameron         150
# 1                     Titanic  James Cameron         100
# 2  Terminator 2: Judgment Day  James Cameron         101
# 3                   True Lies  James Cameron          38
# 4                   The Abyss  James Cameron          24
# 5                      Aliens  James Cameron          67
# 6              The Terminator  James Cameron          74

# %% [markdown]
# ## q9  the total revenues and the budget of the movies directed by James Cameron

# %%
di
# Out:
#          id     budget  popularity     revenue                       title  \
# 0     43597  237000000         150  2787965087                      Avatar
# 19    43622  200000000         100  1845034188                     Titanic
# 170   43876  100000000         101   520000000  Terminator 2: Judgment Day
# 173   43879  115000000          38   378882411                   True Lies
# 344   44184   70000000          24    90000098                   The Abyss
# 1100  46000   18500000          67   183316455                      Aliens
# 1320  47036    6400000          74    78371200              The Terminator
#
#       vote_average  vote_count  director_id  year month        day  \
# 0              7.2       11800         4762  2009   Dec   Thursday
# 19             7.5        7562         4762  1997   Nov    Tuesday
# 170            7.7        4185         4762  1991   Jul     Monday
# 173            6.8        1116         4762  1994   Jul   Thursday
# ...

# %%
di[['budget','revenue']].sum()
# Out:
# budget      746900000
# revenue    5883569439
# dtype: int64

# %%
total=di[['budget','revenue']]

# %%
total
# Out:
#          budget     revenue
# 0     237000000  2787965087
# 19    200000000  1845034188
# 170   100000000   520000000
# 173   115000000   378882411
# 344    70000000    90000098
# 1100   18500000   183316455
# 1320    6400000    78371200

# %%
total.plot(kind='bar',xlabel='budget',ylabel='revenue',title='overall analysis');

# %% [markdown]
# ## q10 how many movies are directed by each directors

# %%
movdir['director_name'].value_counts()
# Out:
# director_name
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Spike Lee             16
#                       ..
# Andrzej Bartkowiak     5
# George Clooney         5
# Judd Apatow            5
# Mike Nichols           5
# Nicole Holofcener      5
# Name: count, Length: 181, dtype: int64

# %%
movdir['director_name'].value_counts().head(10).plot(kind='bar',xlabel='Director Names',ylabel='Number of films',color='r',title='Number of Films');

# %% [markdown]
# ## q11 overall revenue generated directors

# %%
movdir.groupby('director_name')['revenue'].sum()
# Out:
# director_name
# Adam McKay                      859076455
# Adam Shankman                   873562773
# Alejandro González Iñárritu     877979871
# Alex Proyas                     774562458
# Andrew Adamson                 2606859447
#                                   ...
# Wes Craven                      764794281
# Wolfgang Petersen              1615016083
# Woody Allen                     620906323
# Zack Snyder                    2476197387
# Zhang Yimou                     365569811
# Name: revenue, Length: 181, dtype: int64

# %%
movdir
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1459  48359          0           2           0
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# ## q12 which all movies generated revenues greater than 1 billion

# %%
movdir[movdir['revenue']>1000000000][['title','revenue']].reset_index(drop=True)
# Out:
#                                             title     revenue
# 0                                          Avatar  2787965087
# 1                           The Dark Knight Rises  1084939099
# 2      Pirates of the Caribbean: Dead Man's Chest  1065659812
# 3     Pirates of the Caribbean: On Stranger Tides  1045713802
# 4                                         Titanic  1845034188
# 5                                         Skyfall  1108561013
# 6                             Alice in Wonderland  1025491110
# 7                 Transformers: Age of Extinction  1091405097
# 8                                       Furious 7  1506249360
# 9                  Transformers: Dark of the Moon  1123746996
# 10                                The Dark Knight  1004558444
# 11              The Hobbit: An Unexpected Journey  1021103568
# 12  The Lord of the Rings: The Return of the King  1118888979

# %% [markdown]
# ## q13 which all movies are available in 90s

# %%
movdir[movdir['year']<2000].reset_index(drop=True)
# Out:
#         id     budget  popularity     revenue                    title  \
# 0    43622  200000000         100  1845034188                  Titanic
# 1    43667  170000000          40   222104681           Wild Wild West
# 2    43746  140000000          58   553799566               Armageddon
# 3    43761  140000000          24   285444603          Lethal Weapon 4
# 4    43767  135000000          39   361832400  The World Is Not Enough
# ..     ...        ...         ...         ...                      ...
# 423  48323          0           5           0               The Mighty
# 424  48335      60000          27     3221152                       Pi
# 425  48363          0           3      321952           The Last Waltz
# 426  48370      27000          19     3151130                   Clerks
# 427  48376          0           3           0                  Slacker
#
#      vote_average  vote_count  director_id  year month        day  \
# ...

# %% [markdown]
# ## q14 which all movies have voting gretaer than 10k

# %%
movdir[movdir['vote_count']>10000]
# Out:
#         id     budget  popularity     revenue             title  vote_average  \
# 0    43597  237000000         150  2787965087            Avatar           7.2
# 45   43662  185000000         187  1004558444   The Dark Knight           8.2
# 58   43692  165000000         724   675120017      Interstellar           8.1
# 59   43693  160000000         167   825532764         Inception           8.1
# 178  43884  100000000          82   425368238  Django Unchained           7.8
#
#      vote_count  director_id  year month        day      director_name gender
# 0         11800         4762  2009   Dec   Thursday      James Cameron   Male
# 45        12002         4765  2008   Jul  Wednesday  Christopher Nolan   Male
# 58        10867         4765  2014   Nov  Wednesday  Christopher Nolan   Male
# 59        13752         4765  2010   Jul  Wednesday  Christopher Nolan   Male
# 178       10099         4927  2012   Dec    Tuesday  Quentin Tarantino   Male

# %% [markdown]
# ## q15 who is the directer of the nobel award film 'interseller'

# %%
movdir.groupby('title').get_group('Interstellar')
# Out:
#        id     budget  popularity    revenue         title  vote_average  \
# 58  43692  165000000         724  675120017  Interstellar           8.1
#
#     vote_count  director_id  year month        day      director_name gender
# 58       10867         4765  2014   Nov  Wednesday  Christopher Nolan   Male
